# %% [markdown]
# ## Rover Project Test Notebook
# This notebook contains the functions from the lesson and provides the scaffolding you need to test out your mapping methods.  The steps you need to complete in this notebook for the project are the following:
#
# * First just run each of the cells in the notebook, examine the code and the results of each.
# * Run the simulator in "Training Mode" and record some data. Note: the simulator may crash if you try to record a large (longer than a few minutes) dataset, but you don't need a ton of data, just some example images to work with.
# * Change the data directory path (2 cells below) to be the directory where you saved data
# * Test out the functions provided on your data
# * Write new functions (or modify existing ones) to report and map out detections of obstacles and rock samples (yellow rocks)
# * Populate the `process_image()` function with the appropriate steps/functions to go from a raw image to a worldmap.
# * Run the cell that calls `process_image()` using `moviepy` functions to create video output
# * Once you have mapping working, move on to modifying `perception.py` and `decision.py` to allow your rover to navigate and map in autonomous mode!
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# **Run the next cell to get code highlighting in the markdown cells.**

# %%
# %%HTML
# <style> code {background-color : orange !important;} </style>
# Out:
# <style> code {background-color : orange !important;} </style>

# %%
# %matplotlib inline
#%matplotlib qt # Choose %matplotlib qt to plot to an interactive window (note it may show up behind your browser)
# Make some of the relevant imports
import cv2 # OpenCV for perspective transform
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import scipy.misc # For saving images as needed
import glob  # For reading in a list of images from a folder
import imageio
imageio.plugins.ffmpeg.download()

# %% [markdown]
# ## Quick Look at the Data
# There's some example data provided in the `test_dataset` folder.  This basic dataset is enough to get you up and running but if you want to hone your methods more carefully you should record some data of your own to sample various scenarios in the simulator.
#
# Next, read in and display a random image from the `test_dataset` folder

# %%
path = '../test_dataset/IMG/*'
img_list = glob.glob(path)
# Grab a random image and display it
idx = np.random.randint(0, len(img_list)-1)
image = mpimg.imread(img_list[idx])
plt.imshow(image)

# %% [markdown]
# ## Calibration Data
# Read in and display example grid and rock sample calibration images.  You'll use the grid for perspective transform and the rock image for creating a new color selection that identifies these samples of interest.

# %%
# In the simulator you can toggle on a grid on the ground for calibration
# You can also toggle on the rock samples with the 0 (zero) key.  
# Here's an example of the grid and one of the rocks
example_grid = '../calibration_images/example_grid1.jpg'
example_rock = '../calibration_images/example_rock1.jpg'
grid_img = mpimg.imread(example_grid)
rock_img = mpimg.imread(example_rock)

fig = plt.figure(figsize=(12,3))
plt.subplot(121)
plt.imshow(grid_img)
plt.subplot(122)
plt.imshow(rock_img)

# %% [markdown]
# ## Perspective Transform
#
# Define the perspective transform function from the lesson and test it on an image.

# %%
# Define a function to perform a perspective transform
# I've used the example grid image above to choose source points for the
# grid cell in front of the rover (each grid cell is 1 square meter in the sim)
# Define a function to perform a perspective transform
def perspect_transform(img, src, dst):
           
    M = cv2.getPerspectiveTransform(src, dst)
    warped = cv2.warpPerspective(img, M, (img.shape[1], img.shape[0]))# keep same size as input image
    
    return warped


# Define calibration box in source (actual) and destination (desired) coordinates
# These source and destination points are defined to warp the image
# to a grid where each 10x10 pixel square represents 1 square meter
# The destination box will be 2*dst_size on each side
dst_size = 5 
# Set a bottom offset to account for the fact that the bottom of the image 
# is not the position of the rover but a bit in front of it
# this is just a rough guess, feel free to change it!
bottom_offset = 6
source = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
destination = np.float32([[image.shape[1]/2 - dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - 2*dst_size - bottom_offset], 
                  [image.shape[1]/2 - dst_size, image.shape[0] - 2*dst_size - bottom_offset],
                  ])
warped = perspect_transform(grid_img, source, destination)
plt.imshow(warped)
#scipy.misc.imsave('../output/warped_example.jpg', warped)

# %% [markdown]
# ## Color Thresholding
# Define the color thresholding function from the lesson and apply it to the warped image
#
# **TODO:** Ultimately, you want your map to not just include navigable terrain but also obstacles and the positions of the rock samples you're searching for.  Modify this function or write a new function that returns the pixel locations of obstacles (areas below the threshold) and rock samples (yellow rocks in calibration images), such that you can map these areas into world coordinates as well.
# **Hints and Suggestion:**
# * For obstacles you can just invert your color selection that you used to detect ground pixels, i.e., if you've decided that everything above the threshold is navigable terrain, then everthing below the threshold must be an obstacle!
#
#
# * For rocks, think about imposing a lower and upper boundary in your color selection to be more specific about choosing colors.  You can investigate the colors of the rocks (the RGB pixel values) in an interactive matplotlib window to get a feel for the appropriate threshold range (keep in mind you may want different ranges for each of R, G and B!).  Feel free to get creative and even bring in functions from other libraries.  Here's an example of [color selection](http://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html) using OpenCV.
#
# * **Beware However:** if you start manipulating images with OpenCV, keep in mind that it defaults to `BGR` instead of `RGB` color space when reading/writing images, so things can get confusing.

# %%
# Identify pixels above the threshold
# Threshold of RGB > 160 does a nice job of identifying ground pixels only
def color_thresh(img, rgb_thresh=(160, 160, 160),flag = True):
    # Create an array of zeros same xy size as img, but single channel
    color_select = np.zeros_like(img[:,:,0])
    # Require that each pixel be above all three threshold values in RGB
    # above_thresh will now contain a boolean array with "True"
    # where threshold was met
    above_thresh = (img[:,:,0] > rgb_thresh[0]) \
                & (img[:,:,1] > rgb_thresh[1]) \
                & (img[:,:,2] > rgb_thresh[2])
    # Index the array of zeros with the boolean array and set to 1
    if flag: 
        color_select[above_thresh] = 1
    else:
        color_select[~above_thresh] = 1
    # Return the binary image
    return color_select


def color_thresh_rock(img, rgb_thresh=(150, 100, 50),flag = True):
    # Create an array of zeros same xy size as img, but single channel
    color_select = np.zeros_like(img[:,:,0])
    # Require that each pixel be above all three threshold values in RGB
    # above_thresh will now contain a boolean array with "True"
    # where threshold was met
    above_thresh = (img[:,:,0] > rgb_thresh[0]) \
                & (img[:,:,1] > rgb_thresh[1]) \
                & (img[:,:,2] < rgb_thresh[2])
    # Index the array of zeros with the boolean array and set to 1
    if flag: 
        color_select[above_thresh] = 1
    else:
        color_select[~above_thresh] = 1
    # Return the binary image
    return color_select


threshed = color_thresh(warped,flag=True)
plt.imshow(threshed, cmap='gray')
#scipy.misc.imsave('../output/warped_threshed.jpg', threshed*255)

# %% [markdown]
# ## Coordinate Transformations
# Define the functions used to do coordinate transforms and apply them to an image.

# %%
# Define a function to convert from image coords to rover coords
def rover_coords(binary_img):
    # Identify nonzero pixels
    ypos, xpos = binary_img.nonzero()
    # Calculate pixel positions with reference to the rover position being at the 
    # center bottom of the image.  
    x_pixel = -(ypos - binary_img.shape[0]).astype(np.float)
    y_pixel = -(xpos - binary_img.shape[1]/2 ).astype(np.float)
    return x_pixel, y_pixel

# Define a function to convert to radial coords in rover space
def to_polar_coords(x_pixel, y_pixel):
    # Convert (x_pixel, y_pixel) to (distance, angle) 
    # in polar coordinates in rover space
    # Calculate distance to each pixel
    dist = np.sqrt(x_pixel**2 + y_pixel**2)
    # Calculate angle away from vertical for each pixel
    angles = np.arctan2(y_pixel, x_pixel)
    return dist, angles

# Define a function to map rover space pixels to world space
def rotate_pix(xpix, ypix, yaw):
    # Convert yaw to radians
    yaw_rad = yaw * np.pi / 180
    xpix_rotated = (xpix * np.cos(yaw_rad)) - (ypix * np.sin(yaw_rad))
                            
    ypix_rotated = (xpix * np.sin(yaw_rad)) + (ypix * np.cos(yaw_rad))
    # Return the result  
    return xpix_rotated, ypix_rotated

def translate_pix(xpix_rot, ypix_rot, xpos, ypos, scale): 
    # Apply a scaling and a translation
    xpix_translated = (xpix_rot / scale) + xpos
    ypix_translated = (ypix_rot / scale) + ypos
    # Return the result  
    return xpix_translated, ypix_translated


# Define a function to apply rotation and translation (and clipping)
# Once you define the two functions above this function should work
def pix_to_world(xpix, ypix, xpos, ypos, yaw, world_size, scale):
    # Apply rotation
    xpix_rot, ypix_rot = rotate_pix(xpix, ypix, yaw)
    # Apply translation
    xpix_tran, ypix_tran = translate_pix(xpix_rot, ypix_rot, xpos, ypos, scale)
    # Perform rotation, translation and clipping all at once
    x_pix_world = np.clip(np.int_(xpix_tran), 0, world_size - 1)
    y_pix_world = np.clip(np.int_(ypix_tran), 0, world_size - 1)
    # Return the result
    return x_pix_world, y_pix_world

# Grab another random image
idx = np.random.randint(0, len(img_list)-1)
image = mpimg.imread(img_list[idx])
warped = perspect_transform(image, source, destination)
threshed = color_thresh(warped)

# Calculate pixel values in rover-centric coords and distance/angle to all pixels
xpix, ypix = rover_coords(threshed)
dist, angles = to_polar_coords(xpix, ypix)
mean_dir = np.mean(angles)

# Do some plotting
fig = plt.figure(figsize=(12,9))
plt.subplot(221)
plt.imshow(image)
plt.subplot(222)
plt.imshow(warped)
plt.subplot(223)
plt.imshow(threshed, cmap='gray')
plt.subplot(224)
plt.plot(xpix, ypix, '.')
plt.ylim(-160, 160)
plt.xlim(0, 160)
arrow_length = 100
x_arrow = arrow_length * np.cos(mean_dir)
y_arrow = arrow_length * np.sin(mean_dir)
plt.arrow(0, 0, x_arrow, y_arrow, color='red', zorder=2, head_width=10, width=2)

# %% [markdown]
# ## Read in saved data and ground truth map of the world
# The next cell is all setup to read your saved data into a `pandas` dataframe.  Here you'll also read in a "ground truth" map of the world, where white pixels (pixel value = 1) represent navigable terrain.
#
# After that, we'll define a class to store telemetry data and pathnames to images.  When you instantiate this class (`data = Databucket()`) you'll have a global variable called `data` that you can refer to for telemetry and map data within the `process_image()` function in the following cell.

# %%
# Import pandas and read in csv file as a dataframe
import pandas as pd
# Change the path below to your data directory
# If you are in a locale (e.g., Europe) that uses ',' as the decimal separator
# change the '.' to ','
#df = pd.read_csv('../test_dataset/robot_log.csv', delimiter=';', decimal='.')

df = pd.read_csv(r'C:\Users\deeptrivia\Documents\Udacity\robot_log.csv', delimiter=';', decimal='.')

csv_img_list = df["Path"].tolist() # Create list of image pathnames
# Read in ground truth map and create a 3-channel image with it
ground_truth = mpimg.imread('../calibration_images/map_bw.png')
ground_truth_3d = np.dstack((ground_truth*0, ground_truth*255, ground_truth*0)).astype(np.float)

# Creating a class to be the data container
# Will read in saved data from csv file and populate this object
# Worldmap is instantiated as 200 x 200 grids corresponding 
# to a 200m x 200m space (same size as the ground truth map: 200 x 200 pixels)
# This encompasses the full range of output position values in x and y from the sim
class Databucket():
    def __init__(self):
        self.images = csv_img_list  
        self.xpos = df["X_Position"].values
        self.ypos = df["Y_Position"].values
        self.yaw = df["Yaw"].values
        self.count = 0 # This will be a running index
        self.worldmap = np.zeros((200, 200, 3)).astype(np.float)
        self.ground_truth = ground_truth_3d # Ground truth worldmap

# Instantiate a Databucket().. this will be a global variable/object
# that you can refer to in the process_image() function below
data = Databucket()

# %%
data.images
# Out:
# ['C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_40_599.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_40_622.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_40_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_40_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_40_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_40_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_40_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_018.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_41_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_016.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_419.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_752.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_886.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_42_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_018.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_350.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_753.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_829.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_43_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_019.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_152.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_286.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_352.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_486.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_552.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_752.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_819.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_44_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_018.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_153.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_286.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_352.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_552.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_752.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_45_953.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_018.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_152.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_46_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_016.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_152.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_47_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_152.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_48_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_350.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_550.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_616.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_49_950.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_150.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_283.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_350.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_552.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_619.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_686.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_819.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_886.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_50_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_152.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_352.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_553.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_686.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_752.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_886.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_51_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_019.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_152.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_353.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_552.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_52_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_552.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_53_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_352.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_552.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_54_950.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_018.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_552.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_55_950.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_550.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_752.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_56_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_57_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_485.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_618.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_752.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_58_952.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_018.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_085.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_818.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_03_59_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_150.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_285.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_685.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_750.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_00_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_018.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_550.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_01_950.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_550.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_02_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_683.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_03_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_04_950.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_016.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_083.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_05_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_350.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_550.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_06_950.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_416.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_550.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_883.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_07_950.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_218.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_418.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_683.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_816.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_885.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_08_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_884.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_09_951.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_017.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_084.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_151.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_217.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_284.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_351.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_417.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_484.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_551.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_617.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_684.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_751.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_817.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_904.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_10_967.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_034.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_100.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_167.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_233.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_301.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_367.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_433.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_500.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_568.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_633.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_701.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_767.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_834.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_920.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_11_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_051.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_117.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_184.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_251.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_317.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_384.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_451.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_517.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_584.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_651.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_717.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_784.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_851.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_917.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_12_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_050.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_116.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_184.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_250.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_316.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_383.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_450.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_517.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_584.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_717.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_783.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_850.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_916.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_13_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_050.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_116.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_183.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_250.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_316.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_383.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_450.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_517.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_584.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_783.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_850.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_917.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_14_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_050.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_117.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_184.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_250.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_317.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_383.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_450.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_516.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_584.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_717.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_784.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_851.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_917.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_15_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_050.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_116.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_183.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_250.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_316.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_383.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_450.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_516.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_583.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_784.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_16_850.jpg',
# ...
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_182.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_249.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_316.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_449.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_515.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_582.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_649.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_782.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_849.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_916.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_35_982.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_049.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_116.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_182.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_249.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_315.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_449.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_515.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_582.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_649.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_782.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_849.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_915.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_36_982.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_049.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_115.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_183.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_249.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_315.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_449.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_515.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_582.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_649.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_783.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_849.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_915.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_37_982.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_049.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_115.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_182.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_249.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_315.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_449.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_515.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_582.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_649.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_715.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_782.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_849.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_915.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_38_982.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_049.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_115.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_182.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_249.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_316.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_449.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_516.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_583.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_651.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_717.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_784.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_850.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_916.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_39_982.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_049.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_115.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_183.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_249.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_315.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_448.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_515.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_582.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_648.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_715.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_782.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_848.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_915.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_40_981.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_048.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_115.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_182.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_248.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_315.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_448.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_515.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_582.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_648.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_715.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_782.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_848.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_915.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_41_982.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_049.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_115.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_182.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_249.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_315.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_382.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_449.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_515.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_582.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_649.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_783.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_849.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_915.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_42_983.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_051.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_117.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_184.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_252.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_317.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_384.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_451.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_517.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_584.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_783.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_850.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_916.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_43_983.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_050.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_116.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_183.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_250.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_317.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_384.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_450.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_516.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_583.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_717.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_784.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_851.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_917.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_44_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_051.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_117.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_184.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_250.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_317.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_384.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_450.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_517.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_584.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_716.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_784.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_850.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_916.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_45_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_051.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_116.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_183.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_250.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_316.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_384.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_450.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_517.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_583.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_650.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_717.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_783.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_851.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_917.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_46_984.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_47_050.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_47_117.jpg',
#  'C:\\Users\\deeptrivia\\Documents\\Udacity\\IMG\\robocam_2017_10_07_16_04_47_183.jpg',
#  ...]

# %% [markdown]
# ## Write a function to process stored images
#
# Modify the `process_image()` function below by adding in the perception step processes (functions defined above) to perform image analysis and mapping.  The following cell is all set up to use this `process_image()` function in conjunction with the `moviepy` video processing package to create a video from the images you saved taking data in the simulator.
#
# In short, you will be passing individual images into `process_image()` and building up an image called `output_image` that will be stored as one frame of video.  You can make a mosaic of the various steps of your analysis process and add text as you like (example provided below).
#
#
#
# To start with, you can simply run the next three cells to see what happens, but then go ahead and modify them such that the output video demonstrates your mapping process.  Feel free to get creative!

# %%
# Define a function to pass stored images to
# reading rover position and yaw angle from csv file
# This function will be used by moviepy to create an output video
def process_image(img):
    # Example of how to use the Databucket() object defined above
    # to print the current x, y and yaw values 
    # print(data.xpos[data.count], data.ypos[data.count], data.yaw[data.count])
    
    # TODO: 
    # 1) Define source and destination points for perspective transform
    #image = mpimg.imread(img)
    dst_size = 5 
    bottom_offset = 6
    source = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
    destination = np.float32([[image.shape[1]/2 - dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - 2*dst_size - bottom_offset], 
                  [image.shape[1]/2 - dst_size, image.shape[0] - 2*dst_size - bottom_offset],
                  ])


    # 2) Apply perspective transform
    
    warped = perspect_transform(img, source, destination)
    # 3) Apply color threshold to identify navigable terrain/obstacles/rock samples
    navigable = color_thresh(warped)
    obstacles = color_thresh(warped,flag=False)
    rock_samples = color_thresh_rock(warped,flag=False)
    
    # 4) Convert thresholded image pixel values to rover-centric coords
    x_rover_navigable, y_rover_navigable = rover_coords(navigable)
    x_rover_obstacle, y_rover_obstacle = rover_coords(obstacles)
    x_rover_rock, y_rover_rock = rover_coords(rock_samples)
    dist, angles = to_polar_coords(xpix, ypix)
    mean_dir = np.mean(angles)

    # 5) Convert rover-centric pixel values to world coords
    xpos = data.xpos[data.count]
    ypos = data.ypos[data.count]
    yaw = data.yaw[data.count]
    scale = 10
    world_size = data.worldmap.shape[1]
    x_world_navigable,y_world_navigable = pix_to_world(x_rover_navigable, y_rover_navigable, xpos, ypos, yaw, world_size, scale)
    x_world_obstacle,y_world_obstacle = pix_to_world(x_rover_obstacle, y_rover_obstacle, xpos, ypos, yaw, world_size, scale)
    x_world_rock,y_world_rock = pix_to_world(x_rover_rock, y_rover_rock, xpos, ypos, yaw, world_size, scale)
    # 6) Update worldmap (to be displayed on right side of screen)
    data.worldmap[y_world_obstacle, x_world_obstacle, 0] += 1
    data.worldmap[y_world_rock, x_world_rock, 1] += 0
    data.worldmap[y_world_navigable, x_world_navigable, 2] += 1

    # 7) Make a mosaic image, below is some example code
        # First create a blank image (can be whatever shape you like)
    output_image = np.zeros((img.shape[0] + data.worldmap.shape[0], img.shape[1]*2, 3))
        # Next you can populate regions of the image with various output
        # Here I'm putting the original image in the upper left hand corner
    output_image[0:img.shape[0], 0:img.shape[1]] = img

        # Let's create more images to add to the mosaic, first a warped image
    warped = perspect_transform(img, source, destination)
        # Add the warped image in the upper right hand corner
    output_image[0:img.shape[0], img.shape[1]:] = warped

        # Overlay worldmap with ground truth map
    map_add = cv2.addWeighted(data.worldmap, 1, data.ground_truth, 0.5, 0)
        # Flip map overlay so y-axis points upward and add to output_image 
    output_image[img.shape[0]:, 0:data.worldmap.shape[1]] = np.flipud(map_add)


        # Then putting some text over the image
    cv2.putText(output_image,"Populate this image with your analyses to make a video!", (20, 20), 
                cv2.FONT_HERSHEY_COMPLEX, 0.4, (255, 255, 255), 1)
    if data.count < len(data.images) - 1:
        data.count += 1 # Keep track of the index in the Databucket()
    
    return output_image

# %% [markdown]
# ## Make a video from processed image data
# Use the [moviepy](https://zulko.github.io/moviepy/) library to process images and create a video.

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from moviepy.editor import ImageSequenceClip


# Define pathname to save the output video
output = '../output/test_mapping.mp4'
data = Databucket() # Re-initialize data in case you're running this cell multiple times
clip = ImageSequenceClip(data.images, fps=60) # Note: output video will be sped up because 
                                          # recording rate in simulator is fps=25
new_clip = clip.fl_image(process_image) #NOTE: this function expects color images!!
# %time new_clip.write_videofile(output, audio=False)
# Out:
# [MoviePy] >>>> Building video ../output/test_mapping.mp4
# [MoviePy] Writing video ../output/test_mapping.mp4
# 100%|██████████| 2047/2047 [00:45<00:00, 45.32it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ../output/test_mapping.mp4
#
# Wall time: 45.4 s

# %% [markdown]
# ### This next cell should function as an inline video player
# If this fails to render the video, try running the following cell (alternative video rendering method).  You can also simply have a look at the saved mp4 in your `/output` folder

# %%
from IPython.display import HTML
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(output))
# Out:
# <video width="960" height="540" controls>
#   <source src="../output/test_mapping.mp4">
# </video>

# %% [markdown]
# ### Below is an alternative way to create a video in case the above cell did not work.

# %%
import io
import base64
video = io.open(output, 'r+b').read()
encoded_video = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded_video.decode('ascii')))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
import drive_rover

# %%
from decision import decision_step
